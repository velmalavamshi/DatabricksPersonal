# %%
# %sql
-- Check ingestion control table
SELECT 
  *
FROM mde_dev.ai_unstructured_metadata.ingestion_control
ORDER BY created_at DESC;

# %%
# %sql
# DELETE FROM mde_dev.ai_unstructured_metadata.ingestion_control
# WHERE target_delta_table LIKE 'main%'
